# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/student-perfirmance/StudentPerformanceFactors.csv

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Data

# %%
data=pd.read_csv("/kaggle/input/student-perfirmance/StudentPerformanceFactors.csv")
data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # Data Exploration

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
data.shape
# Out:
# (6607, 20)

# %%
data.columns.to_list()
# Out:
# ['Hours_Studied',
#  'Attendance',
#  'Parental_Involvement',
#  'Access_to_Resources',
#  'Extracurricular_Activities',
#  'Sleep_Hours',
#  'Previous_Scores',
#  'Motivation_Level',
#  'Internet_Access',
#  'Tutoring_Sessions',
#  'Family_Income',
#  'Teacher_Quality',
#  'School_Type',
#  'Peer_Influence',
#  'Physical_Activity',
#  'Learning_Disabilities',
#  'Parental_Education_Level',
#  'Distance_from_Home',
#  'Gender',
#  'Exam_Score']

# %%
data.sample(5)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1055             16          62                 High              Medium
# 1714             17          88                  Low                 Low
# 1389             15          85               Medium              Medium
# 632              19          79                 High              Medium
# 2126             13          85                 High                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 1055                         No            4               89
# 1714                         No            5               67
# 1389                         No            8               58
# 632                         Yes           10               59
# 2126                        Yes            6               72
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 1055             High             Yes                  3           Low
# ...

# %%
data.describe().round()
# Out:
#        Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# count         6607.0      6607.0       6607.0           6607.0
# mean            20.0        80.0          7.0             75.0
# std              6.0        12.0          1.0             14.0
# min              1.0        60.0          4.0             50.0
# 25%             16.0        70.0          6.0             63.0
# 50%             20.0        80.0          7.0             75.0
# 75%             24.0        90.0          8.0             88.0
# max             44.0       100.0         10.0            100.0
#
#        Tutoring_Sessions  Physical_Activity  Exam_Score
# count             6607.0             6607.0      6607.0
# mean                 1.0                3.0        67.0
# std                  1.0                1.0         4.0
# min                  0.0                0.0        55.0
# 25%                  1.0                2.0        65.0
# 50%                  1.0                3.0        67.0
# ...

# %%
data.describe(include="O")
# Out:
#        Parental_Involvement Access_to_Resources Extracurricular_Activities  \
# count                  6607                6607                       6607
# unique                    3                   3                          2
# top                  Medium              Medium                        Yes
# freq                   3362                3319                       3938
#
#        Motivation_Level Internet_Access Family_Income Teacher_Quality  \
# count              6607            6607          6607            6529
# unique                3               2             3               3
# top              Medium             Yes           Low          Medium
# freq               3351            6108          2672            3925
#
#        School_Type Peer_Influence Learning_Disabilities  \
# count         6607           6607                  6607
# unique           2              3                     2
# top         Public       Positive                    No
# ...

# %%
data["Parental_Involvement"].value_counts().to_frame()
# Out:
#                       count
# Parental_Involvement
# Medium                 3362
# High                   1908
# Low                    1337

# %%
data["Access_to_Resources"].value_counts().to_frame()
# Out:
#                      count
# Access_to_Resources
# Medium                3319
# High                  1975
# Low                   1313

# %%
data["Extracurricular_Activities"].value_counts().to_frame()
# Out:
#                             count
# Extracurricular_Activities
# Yes                          3938
# No                           2669

# %%
data["Motivation_Level"].value_counts().to_frame()
# Out:
#                   count
# Motivation_Level
# Medium             3351
# Low                1937
# High               1319

# %%
data["Internet_Access"].value_counts().to_frame()
# Out:
#                  count
# Internet_Access
# Yes               6108
# No                 499

# %%
data["Family_Income"].value_counts().to_frame()
# Out:
#                count
# Family_Income
# Low             2672
# Medium          2666
# High            1269

# %%
data["Teacher_Quality"].value_counts().to_frame()
# Out:
#                  count
# Teacher_Quality
# Medium            3925
# High              1947
# Low                657

# %%
data["School_Type"].value_counts().to_frame()
# Out:
#              count
# School_Type
# Public        4598
# Private       2009

# %%
data["Peer_Influence"].value_counts().to_frame()
# Out:
#                 count
# Peer_Influence
# Positive         2638
# Neutral          2592
# Negative         1377

# %%
data["Learning_Disabilities"].value_counts().to_frame()
# Out:
#                        count
# Learning_Disabilities
# No                      5912
# Yes                      695

# %%
data["Parental_Education_Level"].value_counts().to_frame()
# Out:
#                           count
# Parental_Education_Level
# High School                3223
# College                    1989
# Postgraduate               1305

# %%
data["Distance_from_Home"].value_counts().to_frame()
# Out:
#                     count
# Distance_from_Home
# Near                 3884
# Moderate             1998
# Far                   658

# %%
data["Gender"].value_counts().to_frame()
# Out:
#         count
# Gender
# Male     3814
# Female   2793

# %% [markdown]
# # Aggregation Functions Of [Columns]

# %%
data["Hours_Studied"].agg(["count","min","mean","max"]).round().to_frame()
# Out:
#        Hours_Studied
# count         6607.0
# min              1.0
# mean            20.0
# max             44.0

# %%
data["Attendance"].agg(["count","min","mean","max"]).round().to_frame()
# Out:
#        Attendance
# count      6607.0
# min          60.0
# mean         80.0
# max         100.0

# %%
data["Sleep_Hours"].agg(["count","min","mean","max"]).round().to_frame()
# Out:
#        Sleep_Hours
# count       6607.0
# min            4.0
# mean           7.0
# max           10.0

# %%
data["Previous_Scores"].agg(["count","min","mean","max"]).round().to_frame()
# Out:
#        Previous_Scores
# count           6607.0
# min               50.0
# mean              75.0
# max              100.0

# %%
data["Tutoring_Sessions"].agg(["count","min","mean","max"]).round().to_frame()
# Out:
#        Tutoring_Sessions
# count             6607.0
# min                  0.0
# mean                 1.0
# max                  8.0

# %%
data["Physical_Activity"].agg(["count","min","mean","max"]).round().to_frame()
# Out:
#        Physical_Activity
# count             6607.0
# min                  0.0
# mean                 3.0
# max                  6.0

# %%
data["Exam_Score"].agg(["count","min","mean","max"]).round().to_frame()
# Out:
#        Exam_Score
# count      6607.0
# min          55.0
# mean         67.0
# max         101.0

# %% [markdown]
# # Handle Missing Value

# %%
data.isnull().sum().to_frame()
# Out:
#                              0
# Hours_Studied                0
# Attendance                   0
# Parental_Involvement         0
# Access_to_Resources          0
# Extracurricular_Activities   0
# Sleep_Hours                  0
# Previous_Scores              0
# Motivation_Level             0
# Internet_Access              0
# Tutoring_Sessions            0
# Family_Income                0
# Teacher_Quality             78
# School_Type                  0
# Peer_Influence               0
# Physical_Activity            0
# Learning_Disabilities        0
# Parental_Education_Level    90
# Distance_from_Home          67
# Gender                       0
# Exam_Score                   0

# %%
data["Teacher_Quality"]=data["Teacher_Quality"].fillna(data["Teacher_Quality"].mode()[0])

# %%
data["Parental_Education_Level"]=data["Parental_Education_Level"].fillna(data[
                    "Parental_Education_Level"].mode()[0])

# %%
data["Distance_from_Home"]=data["Distance_from_Home"].fillna(data["Distance_from_Home"].mode()[0])

# %%
data.isnull().sum().to_frame()
# Out:
#                             0
# Hours_Studied               0
# Attendance                  0
# Parental_Involvement        0
# Access_to_Resources         0
# Extracurricular_Activities  0
# Sleep_Hours                 0
# Previous_Scores             0
# Motivation_Level            0
# Internet_Access             0
# Tutoring_Sessions           0
# Family_Income               0
# Teacher_Quality             0
# School_Type                 0
# Peer_Influence              0
# Physical_Activity           0
# Learning_Disabilities       0
# Parental_Education_Level    0
# Distance_from_Home          0
# Gender                      0
# Exam_Score                  0

# %% [markdown]
# # Duplicate Entries

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Groupby

# %%
data.groupby("Parental_Education_Level")["Family_Income"].value_counts().to_frame()
# Out:
#                                         count
# Parental_Education_Level Family_Income
# College                  Medium           814
#                          Low              805
#                          High             370
# High School              Low             1344
#                          Medium          1322
#                          High             647
# Postgraduate             Medium           530
#                          Low              523
#                          High             252

# %%
data.groupby("School_Type")["Teacher_Quality"].value_counts().to_frame()
# Out:
#                              count
# School_Type Teacher_Quality
# Private     Medium            1215
#             High               600
#             Low                194
# Public      Medium            2788
#             High              1347
#             Low                463

# %%
data.groupby("School_Type")["Learning_Disabilities"].value_counts().to_frame()
# Out:
#                                    count
# School_Type Learning_Disabilities
# Private     No                      1798
#             Yes                      211
# Public      No                      4114
#             Yes                      484

# %%
data.groupby("School_Type")["Exam_Score"].agg(["min","mean","max","count"]).round()
# Out:
#              min  mean  max  count
# School_Type
# Private       56  67.0  100   2009
# Public        55  67.0  101   4598

# %%
data.groupby("Attendance")["Exam_Score"].agg(["count","min","mean","max"]).sample(5).round()
# Out:
#             count  min  mean  max
# Attendance
# 79            175   58  67.0   73
# 76            185   60  67.0   94
# 95            163   66  70.0   77
# 94            180   64  70.0   76
# 62            152   55  64.0   88

# %%
data.groupby("Parental_Involvement")["Exam_Score"].agg(["min","mean","max","count"]).round()
# Out:
#                       min  mean  max  count
# Parental_Involvement
# High                   57  68.0  100   1908
# Low                    56  66.0  101   1337
# Medium                 55  67.0   97   3362

# %%
data.groupby("Sleep_Hours")["Exam_Score"].agg(["count","min","mean","max"]).round()
# Out:
#              count  min  mean  max
# Sleep_Hours
# 4              309   59  68.0  100
# 5              695   58  67.0   94
# 6             1376   55  67.0  101
# 7             1741   56  67.0   97
# 8             1399   57  67.0   99
# 9              775   58  67.0   98
# 10             312   57  67.0   86

# %%
data.groupby("Extracurricular_Activities")["Exam_Score"].agg(["min","mean","max","count"]).round()
# Out:
#                             min  mean  max  count
# Extracurricular_Activities
# No                           55  67.0   97   2669
# Yes                          57  67.0  101   3938

# %%
data.groupby("Motivation_Level")["Exam_Score"].agg(["min","mean","max","count"]).round()
# Out:
#                   min  mean  max  count
# Motivation_Level
# High               57  68.0   98   1319
# Low                57  67.0  101   1937
# Medium             55  67.0  100   3351

# %%
data.groupby("Learning_Disabilities")["Exam_Score"].agg(["min","mean","max","count"]).round()
# Out:
#                        min  mean  max  count
# Learning_Disabilities
# No                      55  67.0  101   5912
# Yes                     57  66.0   89    695

# %%
data.groupby("Peer_Influence")["Exam_Score"].agg(["min","mean","max","count"]).round()
# Out:
#                 min  mean  max  count
# Peer_Influence
# Negative         55  67.0   99   1377
# Neutral          57  67.0   97   2592
# Positive         57  68.0  101   2638

# %%
data.groupby("Gender")["Exam_Score"].agg(["min","mean","max","count"]).round()
# Out:
#         min  mean  max  count
# Gender
# Female   57  67.0  101   2793
# Male     55  67.0   99   3814

# %%
data.groupby("Family_Income")["Tutoring_Sessions"].agg(["min","mean","max","count"]).round()
# Out:
#                min  mean  max  count
# Family_Income
# High             0   2.0    7   1269
# Low              0   1.0    7   2672
# Medium           0   1.0    8   2666

# %%
data.groupby("Distance_from_Home")["Attendance"].agg(["min","mean","max","count"]).round()
# Out:
#                     min  mean  max  count
# Distance_from_Home
# Far                  60  79.0  100    658
# Moderate             60  80.0  100   1998
# Near                 60  80.0  100   3951

# %% [markdown]
# # Mapping to Simplify

# %%
data["Distance_from_Home"]=data["Distance_from_Home"].map({"Far":0,"Moderate":1,"Near":2})

# %%
data["Parental_Involvement"]=data["Parental_Involvement"].map({"Low":0,"Medium":1,"High":2})

# %%
data["Access_to_Resources"]=data["Access_to_Resources"].map({"Low":0,"Medium":1,"High":2})

# %%
data["Extracurricular_Activities"]=data["Extracurricular_Activities"].map({"No":0,"Yes":1})

# %%
data["Motivation_Level"]=data["Motivation_Level"].map({"Low":0,"Medium":1,"High":2})

# %%
data["Internet_Access"]=data["Internet_Access"].map({"No":0,"Yes":1})

# %%
data["Family_Income"]=data["Family_Income"].map({"Low":0,"Medium":1,"High":2})

# %%
data["Teacher_Quality"]=data["Teacher_Quality"].map({"Low":0,"Medium":1,"High":2})

# %%
data["School_Type"]=data["School_Type"].map({"Private":0,"Public":1})

# %%
data["Peer_Influence"]=data["Peer_Influence"].map({"Neutral":0,"Negative":-1,"Positive":1})

# %%
data["Learning_Disabilities"]=data["Learning_Disabilities"].map({"No":0,"Yes":1})

# %%
data["Parental_Education_Level"]=data["Parental_Education_Level"].map({"High School":0,"Postgraduate":1,"College":2})

# %%
data["Gender"]=data["Gender"].map({"Female":0,"Male":1})

# %%
data
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                    2
# 1                19          64                     0                    1
# 2                24          98                     1                    1
# 3                29          89                     0                    1
# 4                19          92                     1                    1
# ...             ...         ...                   ...                  ...
# 6602             25          69                     2                    1
# 6603             23          76                     2                    1
# 6604             20          90                     1                    0
# 6605             10          86                     2                    2
# 6606             15          67                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# # Saving As Excel Faile

# %%
with pd.ExcelWriter("Student-Perfirmance.xlsx") as writer:
    data.to_excel(writer, sheet_name="Main table", index=False)
